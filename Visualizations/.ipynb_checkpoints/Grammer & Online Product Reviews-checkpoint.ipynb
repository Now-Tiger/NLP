# %% [markdown]
# # Grammar and Online Product Reviews
#
# A list of 71,045 online reviews from 1,000 different products
#
# ---
#
# ## About This Data
# [__download dataset__](https://www.kaggle.com/datasets/datafiniti/grammar-and-online-product-reviews)
#
# This is a list of over 71,045 reviews from 1,000 different products provided by Datafiniti's Product Database. The dataset includes the text and title of the review, the name and manufacturer of the product, reviewer metadata, and more.
#
# Note that this is a sample of a large dataset. The full dataset is available through Datafiniti.

# %%
# %matplotlib inline
import re
from collections import Counter

import pandas as pd
import numpy as np

from nltk.corpus import stopwords
from nltk.probability import FreqDist
from nltk.tokenize import word_tokenize

import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

from warnings import filterwarnings
filterwarnings('ignore')
sns.set_style("whitegrid")
matplotlib.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# ## Load Data:

# %%
data = pd.read_csv('../Data/GrammarandProductReviews.csv')
data.head(2)
# Out:
#                      id            brand  \
# 0  AV13O1A8GV-KLJ3akUyj  Universal Music
# 1  AV14LG0R-jtxr-f38QfS         Lundberg
#
#                                           categories             dateAdded  \
# 0  Movies, Music & Books,Music,R&b,Movies & TV,Mo...  2017-07-25T00:52:42Z
# 1  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...  2017-07-25T05:16:03Z
#
#             dateUpdated          ean  \
# 0  2018-02-05T08:36:58Z  6.02537E+11
# 1  2018-02-05T11:27:45Z  73416000391
#
#                                                 keys  \
# 0  602537205981,universalmusic/14331328,universal...
# 1  lundbergorganiccinnamontoastricecakes/b000fvzw...
#
#                          manufacturer manufacturerNumber  \
# 0  Universal Music Group / Cash Money           14331328
# 1                            Lundberg             574764
#
#                                          name  ...   reviews.id  \
# 0   Pink Friday: Roman Reloaded Re-Up (w/dvd)  ...          NaN
# 1  Lundberg Organic Cinnamon Toast Rice Cakes  ...  100209113.0
#
#   reviews.numHelpful reviews.rating  \
# 0                0.0              5
# 1                NaN              5
#
#                                   reviews.sourceURLs  \
# 0  https://redsky.target.com/groot-domain-api/v1/...
# 1   https://www.walmart.com/reviews/product/29775278
#
#                                         reviews.text  reviews.title  \
# 0  i love this album. it's very good. more to the...   Just Awesome
# 1  Good flavor. This review was collected as part...           Good
#
#    reviews.userCity  reviews.userProvince reviews.username          upc
# 0       Los Angeles                   NaN           Joshua  6.02537E+11
# 1               NaN                   NaN        Dorothy W  73416000391
#
# [2 rows x 25 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71044 entries, 0 to 71043
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    71044 non-null  object
#  1   brand                 71044 non-null  object
#  2   categories            71044 non-null  object
#  3   dateAdded             71044 non-null  object
#  4   dateUpdated           71044 non-null  object
#  5   ean                   39065 non-null  object
#  6   keys                  71044 non-null  object
#  7   manufacturer          70903 non-null  object
#  8   manufacturerNumber    70841 non-null  object
#  9   name                  71044 non-null  object
#  10  reviews.date          70977 non-null  object
#  11  reviews.dateAdded     71044 non-null  object
#  12  reviews.dateSeen      71044 non-null  object
#  13  reviews.didPurchase   32158 non-null  object
#  14  reviews.doRecommend   60429 non-null  object
#  15  reviews.id            32158 non-null  float64
#  16  reviews.numHelpful    32508 non-null  float64
#  17  reviews.rating        71044 non-null  int64
#  18  reviews.sourceURLs    71044 non-null  object
#  19  reviews.text          71008 non-null  object
#  20  reviews.title         70568 non-null  object
#  21  reviews.userCity      5410 non-null   object
#  22  reviews.userProvince  449 non-null    object
#  23  reviews.username      70948 non-null  object
#  24  upc                   71042 non-null  object
# dtypes: float64(2), int64(1), object(22)
# memory usage: 13.6+ MB

# %% [markdown]
# ## Data Preprocessing:
#
# - Select Important features for our task.
# - Replace missing values.
# - Rename columns for simplicity and readablity

# %%
# we can take few columns to our consideration as the part of feature engineering.
# since some columns are nearly empty holding null values.

df = data[['id', 'name', 'reviews.didPurchase', 'reviews.text', 'reviews.rating']]
df.rename(
    columns={
        'name': 'product_name',
        'reviews.didPurchase': 'purchased',
        'reviews.text': 'review_text', 
        'reviews.rating': 'ratings'
    }, inplace=True)

df.head()
# Out:
#                      id                                product_name purchased  \
# 0  AV13O1A8GV-KLJ3akUyj   Pink Friday: Roman Reloaded Re-Up (w/dvd)       NaN
# 1  AV14LG0R-jtxr-f38QfS  Lundberg Organic Cinnamon Toast Rice Cakes      True
# 2  AV14LG0R-jtxr-f38QfS  Lundberg Organic Cinnamon Toast Rice Cakes      True
# 3  AV16khLE-jtxr-f38VFn            K-Y Love Sensuality Pleasure Gel     False
# 4  AV16khLE-jtxr-f38VFn            K-Y Love Sensuality Pleasure Gel     False
#
#                                          review_text  ratings
# 0  i love this album. it's very good. more to the...        5
# 1  Good flavor. This review was collected as part...        5
# 2                                       Good flavor.        5
# 3  I read through the reviews on here before look...        1
# 4  My husband bought this gel for us. The gel cau...        1

# %%
df.isna().sum()
# Out:
# id                  0
# product_name        0
# purchased       38886
# review_text        36
# ratings             0
# dtype: int64

# %%
df.dropna(subset='review_text', inplace=True)
df.isna().sum()
# Out:
# id                  0
# product_name        0
# purchased       38852
# review_text         0
# ratings             0
# dtype: int64

# %% [markdown]
# ## Null Values:
#
# - This __reviews.didPurchased__ (purchased) columm has over __38 thousand null values__.
# - Replacing null values with 'No-review-given' or N/A can help __determine__ the __fake reviews__ posted by the people.
# - Sometimes people can be lazy. They might not post a review even though the product is good.
# - Null reviews are may be generated by bot / simply put - they are fake reviews otherwise there should be entry of the reivew in that respective column.
#
# _this is my intuition, please go with yours or suggest some of your thought or correct me.. Would be great help_

# %%
df['purchased'] = df['purchased'].replace(np.NaN, 'N/A')

# %% [markdown]
# ## Visualizations 📊
#
# --------
#
# ## User Ratings.

# %%
df.head()
# Out:
#                      id                                product_name purchased  \
# 0  AV13O1A8GV-KLJ3akUyj   Pink Friday: Roman Reloaded Re-Up (w/dvd)       N/A
# 1  AV14LG0R-jtxr-f38QfS  Lundberg Organic Cinnamon Toast Rice Cakes      True
# 2  AV14LG0R-jtxr-f38QfS  Lundberg Organic Cinnamon Toast Rice Cakes      True
# 3  AV16khLE-jtxr-f38VFn            K-Y Love Sensuality Pleasure Gel     False
# 4  AV16khLE-jtxr-f38VFn            K-Y Love Sensuality Pleasure Gel     False
#
#                                          review_text  ratings
# 0  i love this album. it's very good. more to the...        5
# 1  Good flavor. This review was collected as part...        5
# 2                                       Good flavor.        5
# 3  I read through the reviews on here before look...        1
# 4  My husband bought this gel for us. The gel cau...        1

# %%
fig = sns.countplot(
    data=df, x=df['ratings'], order=df['ratings'].value_counts().index, color='teal')

for p, label in zip(fig.patches, df.ratings.value_counts()):
    fig.annotate(label, (p.get_x() + .30, p.get_height() + .5))

fig.set_title('Countplot of User Ratings', pad=12)
plt.show()

# %% [markdown]
# ## Fake Reviews vs Genuine Reiviews 🎌

# %%
fig = sns.countplot(data=df, x='purchased', width=.6, palette='PuBu_r');
for p, label in zip(fig.patches, df.purchased.value_counts()):
    fig.annotate(label, (p.get_x() + .25, p.get_height() + .5))

fig.set_title('Genuine No. of Reviews')
plt.show()

# %% [markdown]
# ## Groupby Products 📚

# %%
# df.groupby('product_name').count()
df_prods = df.groupby('id').filter(lambda x: len(x) >= 300)
df_product_groups = df.groupby('id')

len(df_product_groups)
# Out:
# 598

# %%
plt.figure(figsize=(20,40), dpi=100)
sns.countplot(y="id",  hue="ratings", data=df_prods, palette='tab20_r')
plt.savefig('../Data/groupby_products.png')
plt.show()

# %% [markdown]
# ## Top 10 Sold/Selling products 🔋
#
# - Optimize below code:
# - Rather than using product names to show top selling products use id of that product.

# %%
# - top 10 products: 
top_products = df.product_name.value_counts().nlargest(10)

# - Try to sort these products based on largest selling on top then all below in descreasing order.
top_products.plot.barh(color='seagreen', figsize=(12, 8));

# %% [markdown]
# ## Length of the Review 🧪

# %%
df['review_length'] = df['review_text'].apply(len)
df.head()
# Out:
#                      id                                product_name purchased  \
# 0  AV13O1A8GV-KLJ3akUyj   Pink Friday: Roman Reloaded Re-Up (w/dvd)       N/A
# 1  AV14LG0R-jtxr-f38QfS  Lundberg Organic Cinnamon Toast Rice Cakes      True
# 2  AV14LG0R-jtxr-f38QfS  Lundberg Organic Cinnamon Toast Rice Cakes      True
# 3  AV16khLE-jtxr-f38VFn            K-Y Love Sensuality Pleasure Gel     False
# 4  AV16khLE-jtxr-f38VFn            K-Y Love Sensuality Pleasure Gel     False
#
#                                          review_text  ratings  review_length
# 0  i love this album. it's very good. more to the...        5            201
# 1  Good flavor. This review was collected as part...        5             62
# 2                                       Good flavor.        5             12
# 3  I read through the reviews on here before look...        1            696
# 4  My husband bought this gel for us. The gel cau...        1            132

# %%
sns.set(font_scale=2.0)

plt.figure(figsize=(10, 28))
g = sns.FacetGrid(df,col='ratings', height=5)
g.map(plt.hist,'review_length',);

# %% [markdown]
# ## Check which words are appearing most in all reviews 📋
#
# - Create a new dataframe.
# - Clean review text: Lowercase every word, remove punctuations, numbers etc.
# - Save all that in new column;
# 1. Tokenize very word
# 2. Remove Stopwords
# 3. Plot FreqDistribution for most appearing words.

# %%
reviews = df[['review_text', 'ratings', 'review_length']]
reviews.head()
# Out:
#                                          review_text  ratings  review_length
# 0  i love this album. it's very good. more to the...        5            201
# 1  Good flavor. This review was collected as part...        5             62
# 2                                       Good flavor.        5             12
# 3  I read through the reviews on here before look...        1            696
# 4  My husband bought this gel for us. The gel cau...        1            132

# %%
reviews['cleaned_review'] = reviews['review_text'].str.replace(r'[^\w\s]', '', regex=True)
reviews['cleaned_review'] = reviews['cleaned_review'].str.replace(r'\[[^()]*\]', '', regex=True)
reviews['cleaned_review'] = reviews['cleaned_review'].str.replace(r'[0-9]', '', regex=True)
reviews['cleaned_review'] = reviews['cleaned_review'].apply(lambda x: re.sub(' +', ' ', x))
reviews['cleaned_review'] = reviews['cleaned_review'].apply(lambda x: str(x).lower())

# %%
# ** CONTINUE FROM HERE **
