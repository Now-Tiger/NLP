# %%
from __future__ import annotations
from warnings import filterwarnings
from pathlib import Path

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import seaborn.objects as so

pd.options.display.max_columns= 200
sns.set_style('darkgrid')
filterwarnings('ignore')

# %%
DATAFILE = Path('..') / 'Data' / 'survey_results_public.csv'

# %%
data = pd.read_csv(DATAFILE)
data.drop(columns='Unnamed: 0', axis=1, inplace=True)
data.head()
# Out:
#    ResponseId                      MainBranch  \
# 0       27590  I am a developer by profession
# 1       19538  I am a developer by profession
# 2       18912  I am a developer by profession
# 3       17780  I am a developer by profession
# 4       35509  I am a developer by profession
#
#                                Employment  \
# 0                     Employed, full-time
# 1                     Employed, full-time
# 2                     Employed, full-time
# 3  Employed, full-time;Student, full-time
# 4                     Employed, full-time
#
#                              RemoteWork  \
# 0  Hybrid (some remote, some in-person)
# 1  Hybrid (some remote, some in-person)
# 2  Hybrid (some remote, some in-person)
# 3                          Fully remote
# 4                          Fully remote
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1           Hobby;Contribute to open-source projects
# 2                       I don’t code outside of work
# 3  Hobby;Contribute to open-source projects;Freel...
# 4           Hobby;Contribute to open-source projects
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 0  Other online resources (e.g., videos, blogs, f...
# 1  Books / Physical media;Other online resources ...
# 2  Books / Physical media;Other online resources ...
# 3  Books / Physical media;School (i.e., Universit...
# 4     Books / Physical media;Other (please specify):
#
#                                      LearnCodeOnline   LearnCodeCoursesCert  \
# 0  Technical documentation;Written Tutorials;Stac...            Udemy;Other
# 1  Technical documentation;Blogs;Stack Overflow;O...         Coursera;Udemy
# 2  Blogs;Programming Games;Stack Overflow;Video-b...         Coursera;Udemy
# 3                                                NaN  Udemy;Pluralsight;edX
# 4                                                NaN                    NaN
#
#           YearsCode      YearsCodePro  \
# 0  Less than 1 year  Less than 1 year
# 1                12                10
# 2                15                 9
# 3                17               NaN
# 4                38                28
#
#                                              DevType  \
# 0                                Developer, back-end
# 1                                Engineering manager
# 2                              Developer, full-stack
# 3                      Developer, full-stack;Student
# 4  Developer, full-stack;Developer, QA or test;Cl...
#
#                     OrgSize              PurchaseInfluence  \
# 0        20 to 99 employees  I have little or no influence
# 1      100 to 499 employees          I have some influence
# 2  10,000 or more employees  I have little or no influence
# 3                       NaN                            NaN
# 4        20 to 99 employees          I have some influence
#
#                                           BuyNewTool  \
# 0                    Ask developers I know/work with
# 1  Start a free trial;Visit developer communities...
# 2                                 Start a free trial
# 3  Visit developer communities like Stack Overflo...
# 4  Other (please specify):;Start a free trial;Ask...
#
#                                              Country              Currency  \
# 0                                           Slovakia     EUR European Euro
# 1                                              India     INR\tIndian rupee
# 2                                             Canada  CAD\tCanadian dollar
# 3                                             Turkey                   NaN
# 4  United Kingdom of Great Britain and Northern I...   GBP\tPound sterling
#
#    CompTotal CompFreq                             LanguageHaveWorkedWith  \
# 0     1200.0  Monthly              Bash/Shell;Java;PowerShell;Python;SQL
# 1        NaN      NaN       C;C#;C++;JavaScript;Objective-C;Python;Swift
# 2   150000.0   Yearly                  C#;Java;JavaScript;SQL;TypeScript
# 3        NaN      NaN  Bash/Shell;C#;HTML/CSS;JavaScript;Python;SQL;T...
# 4    72000.0   Yearly  Assembly;Bash/Shell;C;Groovy;JavaScript;Perl;P...
#
#                              LanguageWantToWorkWith  \
# 0  Bash/Shell;Java;JavaScript;PowerShell;Python;SQL
# 1                                 JavaScript;Python
# 2                 C#;Java;JavaScript;SQL;TypeScript
# 3                                       Scala;Swift
# 4  Assembly;Bash/Shell;C;JavaScript;Perl;Python;SQL
#
#                               DatabaseHaveWorkedWith  \
# 0                           MariaDB;MySQL;PostgreSQL
# 1  DynamoDB;Elasticsearch;Microsoft SQL Server;Mo...
# 2                    Microsoft SQL Server;PostgreSQL
# 3  Couchbase;Elasticsearch;Microsoft SQL Server;M...
# 4                                             SQLite
#
#            DatabaseWantToWorkWith               PlatformHaveWorkedWith  \
# 0      MariaDB;MongoDB;PostgreSQL                                  NaN
# 1  DynamoDB;Elasticsearch;MongoDB                  AWS;Microsoft Azure
# 2                      PostgreSQL                      Microsoft Azure
# 3      Firebase Realtime Database  AWS;Firebase;Microsoft Azure;VMware
# 4                          SQLite                                  AWS
#
#   PlatformWantToWorkWith                             WebframeHaveWorkedWith  \
# 0                    NaN                                             Django
# 1       AWS;Google Cloud                            Django;Node.js;React.js
# 2    AWS;Microsoft Azure          Angular.js;ASP.NET;ASP.NET Core ;React.js
# 3                    NaN  Angular;Angular.js;ASP.NET;ASP.NET Core ;jQuer...
# 4                    AWS                                                NaN
#
#              WebframeWantToWorkWith          MiscTechHaveWorkedWith  \
# 0                    Angular;Django                          Spring
# 1          Next.js;Node.js;React.js                    React Native
# 2  Angular.js;ASP.NET;ASP.NET Core                           Spring
# 3                               NaN  .NET;Ionic;React Native;Spring
# 4                               NaN                             GTK
#
#   MiscTechWantToWorkWith               ToolsTechHaveWorkedWith  \
# 0                 Spring                                   NaN
# 1           Apache Kafka  Docker;Homebrew;Kubernetes;Terraform
# 2                    NaN                            Docker;npm
# 3   Flutter;Hadoop;NumPy            Docker;Kubernetes;npm;Yarn
# 4                    GTK     Ansible;Docker;Homebrew;Terraform
#
#                 ToolsTechWantToWorkWith  \
# 0                                   NaN
# 1  Docker;Homebrew;Kubernetes;Terraform
# 2                 Docker;Kubernetes;npm
# 3                                   NaN
# 4               Ansible;Docker;Homebrew
#
#                         NEWCollabToolsHaveWorkedWith  \
# 0                                           IntelliJ
# 1    Android Studio;PyCharm;Visual Studio Code;Xcode
# 2                   Visual Studio;Visual Studio Code
# 3  Notepad++;PyCharm;Rider;Sublime Text;Visual St...
# 4                                  Nano;Sublime Text
#
#                  NEWCollabToolsWantToWorkWith  \
# 0  Android Studio;IntelliJ;Visual Studio Code
# 1                  PyCharm;Visual Studio Code
# 2            Visual Studio;Visual Studio Code
# 3                                         NaN
# 4                           Nano;Sublime Text
#
#                        OpSysProfessional use  \
# 0                                    Windows
# 1                                      macOS
# 2  Windows;Windows Subsystem for Linux (WSL)
# 3                                        NaN
# 4                                Linux-based
#
#                                    OpSysPersonal use VersionControlSystem  \
# 0                                            Windows                  Git
# 1                                            Windows                  Git
# 2                                            Windows                  Git
# 3  Linux-based;Windows;Windows Subsystem for Linu...        Git;Mercurial
# 4          Linux-based;macOS;Other (please specify):                  Git
#
#                                        VCInteraction  VCHostingPersonal use  \
# 0                           Code editor;Command-line                    NaN
# 1  Command-line;Dedicated version control GUI app...                    NaN
# 2  Code editor;Dedicated version control GUI appl...                    NaN
# 3  Code editor;Command-line;Version control hosti...                    NaN
# 4                                       Command-line                    NaN
#
#    VCHostingProfessional use          OfficeStackAsyncHaveWorkedWith  \
# 0                        NaN                    Jira Work Management
# 1                        NaN         Confluence;Jira Work Management
# 2                        NaN                                     NaN
# 3                        NaN  Confluence;Jira Work Management;Trello
# 4                        NaN                                     NaN
#
#            OfficeStackAsyncWantToWorkWith  \
# 0                    Jira Work Management
# 1  Confluence;Jira Work Management;Notion
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#                        OfficeStackSyncHaveWorkedWith  \
# 0                                    Microsoft Teams
# 1                         Microsoft Teams;Slack;Zoom
# 2                                        Google Chat
# 3  Cisco Webex Teams;Google Chat;Microsoft Teams;...
# 4                                         Slack;Zoom
#
#   OfficeStackSyncWantToWorkWith      Blockchain  \
# 0               Microsoft Teams     Indifferent
# 1    Microsoft Teams;Slack;Zoom       Favorable
# 2               Microsoft Teams          Unsure
# 3                           NaN  Very favorable
# 4         Mattermost;Slack;Zoom     Indifferent
#
#                       NEWSOSites             SOVisitFreq SOAccount  \
# 0                 Stack Overflow   Daily or almost daily       Yes
# 1                 Stack Overflow    A few times per week       Yes
# 2  Stack Overflow;Stack Exchange   Daily or almost daily       Yes
# 3  Collectives on Stack Overflow  Multiple times per day       Yes
# 4  Stack Overflow;Stack Exchange    A few times per week        No
#
#                                           SOPartFreq           SOComm  \
# 0  I have never participated in Q&A on Stack Over...          Neutral
# 1                Less than once per month or monthly  Yes, definitely
# 2                Less than once per month or monthly    Yes, somewhat
# 3                             Multiple times per day   No, not at all
# 4                                                NaN   No, not really
#
#                Age Gender Trans                Sexuality Ethnicity  \
# 0  25-34 years old    Man    No  Straight / Heterosexual     White
# 1  25-34 years old    Man   NaN                      NaN    Indian
# 2  25-34 years old    Man    No  Straight / Heterosexual    Indian
# 3  35-44 years old    Man    No                 Bisexual     White
# 4  35-44 years old    Man    No  Straight / Heterosexual     White
#
#        Accessibility                                       MentalHealth  \
# 0  None of the above                                  None of the above
# 1                NaN                                                NaN
# 2  None of the above                                  None of the above
# 3  None of the above  Or, in your own words:;I have a concentration ...
# 4  None of the above  I have a mood or emotional disorder (e.g., dep...
#
#   TBranch                   ICorPM  WorkExp                 Knowledge_1  \
# 0     Yes  Independent contributor      3.0              Strongly agree
# 1     Yes           People manager     13.0                       Agree
# 2     Yes  Independent contributor      8.0  Neither agree nor disagree
# 3     Yes  Independent contributor     16.0                       Agree
# 4     Yes  Independent contributor     26.0              Strongly agree
#
#   Knowledge_2                 Knowledge_3                 Knowledge_4  \
# 0       Agree  Neither agree nor disagree              Strongly agree
# 1       Agree                       Agree  Neither agree nor disagree
# 2    Disagree                       Agree                       Agree
# 3       Agree                       Agree              Strongly agree
# 4    Disagree  Neither agree nor disagree                       Agree
#
#                   Knowledge_5                 Knowledge_6  \
# 0              Strongly agree  Neither agree nor disagree
# 1                       Agree  Neither agree nor disagree
# 2                       Agree                       Agree
# 3              Strongly agree              Strongly agree
# 4  Neither agree nor disagree                       Agree
#
#                   Knowledge_7       Frequency_1       Frequency_2  \
# 0  Neither agree nor disagree  1-2 times a week  1-2 times a week
# 1  Neither agree nor disagree  1-2 times a week  1-2 times a week
# 2  Neither agree nor disagree             Never             Never
# 3                       Agree  1-2 times a week  3-5 times a week
# 4           Strongly disagree  1-2 times a week  10+ times a week
#
#         Frequency_3        TimeSearching               TimeAnswering  \
# 0  1-2 times a week  15-30 minutes a day  Less than 15 minutes a day
# 1  1-2 times a week  30-60 minutes a day         30-60 minutes a day
# 2             Never  30-60 minutes a day  Less than 15 minutes a day
# 3  3-5 times a week  30-60 minutes a day         30-60 minutes a day
# 4             Never  30-60 minutes a day         15-30 minutes a day
#
#       Onboarding                                   ProfessionalTech  \
# 0     Just right  DevOps function;Microservices;Continuous integ...
# 1  Somewhat long  DevOps function;Microservices;Developer portal...
# 2     Just right  DevOps function;Microservices;Continuous integ...
# 3     Just right  Innersource initiative;DevOps function;Microse...
# 4     Just right  Continuous integration (CI) and (more often) c...
#
#   TrueFalse_1 TrueFalse_2 TrueFalse_3           SurveyLength  \
# 0          No          No         Yes  Appropriate in length
# 1         Yes         Yes         Yes               Too long
# 2          No          No          No  Appropriate in length
# 3         Yes         Yes         Yes               Too long
# 4         Yes         Yes         Yes  Appropriate in length
#
#                    SurveyEase  ConvertedCompYearly
# 0  Neither easy nor difficult              15360.0
# 1  Neither easy nor difficult                  NaN
# 2                        Easy             117126.0
# 3  Neither easy nor difficult                  NaN
# 4  Neither easy nor difficult              90460.0

# %%
data.shape
# Out:
# (65941, 79)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65941 entries, 0 to 65940
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ResponseId                      65941 non-null  int64
#  1   MainBranch                      65941 non-null  object
#  2   Employment                      64549 non-null  object
#  3   RemoteWork                      53126 non-null  object
#  4   CodingActivities                53072 non-null  object
#  5   EdLevel                         64427 non-null  object
#  6   LearnCode                       64435 non-null  object
#  7   LearnCodeOnline                 45592 non-null  object
#  8   LearnCodeCoursesCert            26479 non-null  object
#  9   YearsCode                       64213 non-null  object
#  10  YearsCodePro                    46669 non-null  object
#  11  DevType                         55201 non-null  object
#  12  OrgSize                         45934 non-null  object
#  13  PurchaseInfluence               45869 non-null  object
#  14  BuyNewTool                      61156 non-null  object
#  15  Country                         64605 non-null  object
#  16  Currency                        46140 non-null  object
#  17  CompTotal                       34626 non-null  float64
#  18  CompFreq                        40008 non-null  object
#  19  LanguageHaveWorkedWith          63895 non-null  object
#  20  LanguageWantToWorkWith          60354 non-null  object
#  21  DatabaseHaveWorkedWith          54137 non-null  object
#  22  DatabaseWantToWorkWith          45926 non-null  object
#  23  PlatformHaveWorkedWith          44980 non-null  object
#  24  PlatformWantToWorkWith          36423 non-null  object
#  25  WebframeHaveWorkedWith          48260 non-null  object
#  26  WebframeWantToWorkWith          41571 non-null  object
#  27  MiscTechHaveWorkedWith          40434 non-null  object
#  28  MiscTechWantToWorkWith          33085 non-null  object
#  29  ToolsTechHaveWorkedWith         48776 non-null  object
#  30  ToolsTechWantToWorkWith         42002 non-null  object
#  31  NEWCollabToolsHaveWorkedWith    63323 non-null  object
#  32  NEWCollabToolsWantToWorkWith    57757 non-null  object
#  33  OpSysProfessional use           58972 non-null  object
#  34  OpSysPersonal use               63884 non-null  object
#  35  VersionControlSystem            64250 non-null  object
#  36  VCInteraction                   61350 non-null  object
#  37  VCHostingPersonal use           0 non-null      float64
#  38  VCHostingProfessional use       0 non-null      float64
#  39  OfficeStackAsyncHaveWorkedWith  41622 non-null  object
#  40  OfficeStackAsyncWantToWorkWith  28936 non-null  object
#  41  OfficeStackSyncHaveWorkedWith   55921 non-null  object
#  42  OfficeStackSyncWantToWorkWith   42945 non-null  object
#  43  Blockchain                      63973 non-null  object
#  44  NEWSOSites                      64242 non-null  object
#  45  SOVisitFreq                     63878 non-null  object
#  46  SOAccount                       64433 non-null  object
#  47  SOPartFreq                      52403 non-null  object
#  48  SOComm                          64285 non-null  object
#  49  Age                             63863 non-null  object
#  50  Gender                          63776 non-null  object
#  51  Trans                           63290 non-null  object
#  52  Sexuality                       59962 non-null  object
#  53  Ethnicity                       62542 non-null  object
#  54  Accessibility                   60528 non-null  object
#  55  MentalHealth                    59822 non-null  object
#  56  TBranch                         47432 non-null  object
#  57  ICorPM                          32662 non-null  object
#  58  WorkExp                         33097 non-null  float64
#  59  Knowledge_1                     32237 non-null  object
#  60  Knowledge_2                     31489 non-null  object
#  61  Knowledge_3                     31638 non-null  object
#  62  Knowledge_4                     31599 non-null  object
#  63  Knowledge_5                     31531 non-null  object
#  64  Knowledge_6                     31506 non-null  object
#  65  Knowledge_7                     31495 non-null  object
#  66  Frequency_1                     31835 non-null  object
#  67  Frequency_2                     31809 non-null  object
#  68  Frequency_3                     31066 non-null  object
#  69  TimeSearching                   32583 non-null  object
#  70  TimeAnswering                   32422 non-null  object
#  71  Onboarding                      32123 non-null  object
#  72  ProfessionalTech                31420 non-null  object
#  73  TrueFalse_1                     32236 non-null  object
#  74  TrueFalse_2                     32148 non-null  object
#  75  TrueFalse_3                     32182 non-null  object
#  76  SurveyLength                    63423 non-null  object
#  77  SurveyEase                      63468 non-null  object
#  78  ConvertedCompYearly             34306 non-null  float64
# dtypes: float64(5), int64(1), object(73)
# memory usage: 39.7+ MB

# %% [markdown]
# ## Sample of the dataset:

# %%
subset = data.sample(frac=.30)
subset.shape
# Out:
# (19782, 79)

# %%
# subset.to_csv(PATH / 'survey_subset_stackoverflow.csv', index=False)

# %% [markdown]
# # Unique Columns:

# %%
# -- getting started with some limited number of columns --
df = subset[['Employment', 'DevType', 'RemoteWork', 'EdLevel', 'Age', 'Gender',
             'LanguageHaveWorkedWith', 'YearsCode', 'Country', 
             'CompFreq', 'ConvertedCompYearly',
            ]].copy()
df.head(3)
# Out:
#                                               Employment  \
# 42176                                Employed, full-time
# 59739             Student, full-time;Employed, part-time
# 21911  Independent contractor, freelancer, or self-em...
#
#                                                  DevType  \
# 42176  Cloud infrastructure engineer;Security profess...
# 59739  Engineer, site reliability;Developer, full-sta...
# 21911  Developer, back-end;Developer, desktop or ente...
#
#                                  RemoteWork  \
# 42176  Hybrid (some remote, some in-person)
# 59739                          Fully remote
# 21911                          Fully remote
#
#                                                  EdLevel              Age  \
# 42176    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  25-34 years old
# 59739       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18-24 years old
# 21911  Some college/university study without earning ...  25-34 years old
#
#                   Gender                             LanguageHaveWorkedWith  \
# 42176  Prefer not to say            Bash/Shell;JavaScript;PowerShell;Python
# 59739                Man  Assembly;Bash/Shell;C;C++;Dart;Go;Java;JavaScr...
# 21911                Man                  C#;HTML/CSS;JavaScript;PowerShell
#
#       YearsCode                                            Country CompFreq  \
# 42176        14  United Kingdom of Great Britain and Northern I...   Yearly
# 59739        10                                         Bangladesh      NaN
# 21911        10  United Kingdom of Great Britain and Northern I...   Yearly
#
#        ConvertedCompYearly
# 42176             150767.0
# 59739                  NaN
# 21911             138203.0

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19782 entries, 42176 to 1864
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Employment              19337 non-null  object
#  1   DevType                 16502 non-null  object
#  2   RemoteWork              15881 non-null  object
#  3   EdLevel                 19304 non-null  object
#  4   Age                     19128 non-null  object
#  5   Gender                  19105 non-null  object
#  6   LanguageHaveWorkedWith  19160 non-null  object
#  7   YearsCode               19245 non-null  object
#  8   Country                 19356 non-null  object
#  9   CompFreq                12016 non-null  object
#  10  ConvertedCompYearly     10319 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 1.8+ MB

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# ConvertedCompYearly       9463
# CompFreq                  7766
# RemoteWork                3901
# DevType                   3280
# Gender                     677
# Age                        654
# LanguageHaveWorkedWith     622
# YearsCode                  537
# EdLevel                    478
# Employment                 445
# Country                    426
# dtype: int64

# %% [markdown]
# ## Data Cleaning & Preparation:

# %%
df.RemoteWork = df.RemoteWork.map({
    'Fully remote' : 'remote', 
    'Hybrid (some remote, some in-person)' : 'hybrid', 
    'Full in-person': 'onsite'
})
most_frequent_worktype = df.RemoteWork.mode()[0]
df.RemoteWork = df.RemoteWork.replace(np.NaN, most_frequent_worktype, regex=True)
df.RemoteWork = df.RemoteWork.astype("category")

# %%
df['DevType'] = df['DevType'].replace(np.NaN, 'Developer', regex=True)
df['DevType'] = df['DevType'].astype('string')

# %%
df['Gender'] = df['Gender'].map({
    'Man' : 'male', 
    'Woman' : 'female', 
    'Prefer not to say' : 'not mentioned', 
    'Non-binary, genderqueer, or gender non-conforming' : 'non-confirming',
    'Or, in your own words:' : 'non-confirming',
    'Man;Non-binary, genderqueer, or gender non-conforming' : 'non-confirming',
    'Woman;Non-binary, genderqueer, or gender non-conforming' : 'non-confirming',
    'Man;Or, in your own words:' : 'non-confirming',
    'Man;Woman' : 'non-confirming',
    'Man;Woman;Non-binary, genderqueer, or gender non-conforming' : 'non-confirming',
    'Or, in your own words:;Woman;Non-binary, genderqueer, or gender non-conforming' : 'non-confirming',
    'Man;Or, in your own words:;Woman;Non-binary, genderqueer, or gender non-conforming' : 'non-confirming',
    'Or, in your own words:;Non-binary, genderqueer, or gender non-conforming' : 'non-confirming',
    'Or, in your own words:;Woman' : 'non-confirming',
    'Man;Or, in your own words:;Non-binary, genderqueer, or gender non-conforming' : 'non-confirming',
    'Man;Or, in your own words:;Woman' : 'non-confirming',
})

df['Gender'] = df['Gender'].replace(np.NaN, df['Gender'].mode()[0], regex=True)
df['Gender'] = df['Gender'].astype('category')

# %%
df['Age'] = df['Age'].replace(np.NaN, df['Age'].mode()[0], regex=True)
df['Age'] = df['Age'].astype('category')

# %%
df['LanguageHaveWorkedWith'] = df['LanguageHaveWorkedWith'].replace(
    np.NaN, df['LanguageHaveWorkedWith'].mode()[0], regex=True)

df['LanguageHaveWorkedWith'] = df['LanguageHaveWorkedWith'].astype('string')

# %%
df['YearsCode'] = df['YearsCode'].str.replace('Less than 1 year', '1', regex=True)
df['YearsCode'] = df['YearsCode'].str.replace('More than 50 years', '50', regex=True)
df['YearsCode'] = df['YearsCode'].replace(np.NaN, '0', regex=True)
df['YearsCode'] = df['YearsCode'].astype('int')

# %%
df['EdLevel'] = df['EdLevel'].map({
    'Bachelor’s degree (B.A., B.S., B.Eng., etc.)' : 'bachelors',
    'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)' : 'masters',
    'Some college/university study without earning a degree' : 'no degree',
    'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)' : 'school',
    'Other doctoral degree (Ph.D., Ed.D., etc.)' : 'doctorate',
    'Associate degree (A.A., A.S., etc.)' : 'associate degree',
    'Primary/elementary school' : 'school',
    'Something else' : 'not mentioned',
    'Professional degree (JD, MD, etc.)' : 'professional degree (JD, MD, etc.)'
}) 
df['EdLevel'] = df['EdLevel'].replace(np.NaN, df['EdLevel'].mode()[0], regex=True)
df['EdLevel'] = df['EdLevel'].astype('category')

# %%
df['Employment'] = df['Employment'].replace(np.NaN, df['Employment'].mode()[0], regex=True)
df['Employment'] = df['Employment'].astype('category')

# %%
df['CompFreq'] = df['CompFreq'].replace(np.NaN, 'Yearly', regex=True)
df['CompFreq'] = df['CompFreq'].astype('category')

# %%
df['Country'] = df['Country'].replace(np.NaN, df['Country'].mode()[0], regex=True)
df['Country'] = df['Country'].astype('string')

# %%
df['ConvertedCompYearly'] = df['ConvertedCompYearly'].replace(np.NaN, df.ConvertedCompYearly.mean())

# %% [markdown]
# ## EDA: Visualizations 📊

# %%
plt.figure(figsize=(12, 8), dpi=80)

ax = sns.countplot(
    data=df, 
    x='Gender', 
    order=df['Gender'].value_counts().index, 
    palette="Set2_r", 
    width=.6)

for p, label in zip(ax.patches, df.Gender.value_counts()):
    ax.annotate(label, (p.get_x() + .25, p.get_height() + .5))

ax.set_xlabel('Genders')
ax.set_ylabel('Count')
ax.set_title('Gender-Categories')

plt.show()

# %%
plt.figure(figsize=(12, 8), dpi=80)
ax = sns.scatterplot(
        data=df, 
        x='YearsCode', 
        y='ConvertedCompYearly', 
        alpha=.7,
        hue='Age',
        legend='auto', 
        palette="Set1"
);

ax.set_title("Years of coding vs Compensation Yearly")
ax.set_xlabel("Years")
ax.set_ylabel("Compensation")
plt.show()

# %%
p = so.Plot(data=df, x='RemoteWork', y='ConvertedCompYearly', color='Gender')
p.add(so.Dash(alpha=.5), so.Dodge())

# %%
sns.catplot(df, x='ConvertedCompYearly', y='Gender', palette='Paired', aspect=1.4, alpha=.6);
sns.rugplot(df, x='ConvertedCompYearly');

# %%
ax = sns.catplot( 
    df, 
    x='RemoteWork', 
    y='ConvertedCompYearly', 
    kind='bar',
    height=5,
    aspect=1.4,
    palette="tab20_r", 
    alpha=.6
)
ax.set_axis_labels("", "Compensation Yearly");

# %%
ax = sns.catplot( 
    df, 
    x='RemoteWork', 
    y='ConvertedCompYearly', 
    col='Gender', 
    kind='bar', 
    height=4, 
    aspect=.6,
    palette="Set3_r"
)
ax.set_axis_labels("", "Compensation Yearly")
ax.set_xticklabels(['Hybrid', 'Onsite', 'Remote'])
ax.set_titles("{col_var} : {col_name}");

# %%
p = so.Plot(df, 'YearsCode', color='Age')
p.add(so.Bars(), so.Count(), so.Stack())

# %%
sns.stripplot(df, y='Age', x='ConvertedCompYearly', palette='Paired', alpha=.6)
sns.rugplot(df, x='ConvertedCompYearly');
